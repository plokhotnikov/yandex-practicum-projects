# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Постановка задачи</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Первичный-анализ-данных" data-toc-modified-id="Первичный-анализ-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Первичный анализ данных</a></span></li><li><span><a href="#Устранение-дубликатов" data-toc-modified-id="Устранение-дубликатов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Устранение дубликатов</a></span></li><li><span><a href="#Целевой-признак-price" data-toc-modified-id="Целевой-признак-price-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Целевой признак price</a></span></li><li><span><a href="#Категориальные-признаки" data-toc-modified-id="Категориальные-признаки-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Категориальные признаки</a></span></li><li><span><a href="#Модель-на-сырых-данных" data-toc-modified-id="Модель-на-сырых-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Модель на сырых данных</a></span></li><li><span><a href="#Предобработка-числовых-признаков" data-toc-modified-id="Предобработка-числовых-признаков-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Предобработка числовых признаков</a></span><ul class="toc-item"><li><span><a href="#registration_year" data-toc-modified-id="registration_year-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>registration_year</a></span></li><li><span><a href="#kilometer" data-toc-modified-id="kilometer-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>kilometer</a></span></li><li><span><a href="#power" data-toc-modified-id="power-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>power</a></span></li><li><span><a href="#registration_month" data-toc-modified-id="registration_month-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>registration_month</a></span></li></ul></li><li><span><a href="#Подготовка-выборок" data-toc-modified-id="Подготовка-выборок-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Подготовка выборок</a></span><ul class="toc-item"><li><span><a href="#Кодирование-категориальных-признаков" data-toc-modified-id="Кодирование-категориальных-признаков-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Кодирование категориальных признаков</a></span></li><li><span><a href="#Масштабирование" data-toc-modified-id="Масштабирование-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Масштабирование</a></span></li></ul></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#XGBRegressor" data-toc-modified-id="XGBRegressor-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>XGBRegressor</a></span></li><li><span><a href="#CatBoostRegressor" data-toc-modified-id="CatBoostRegressor-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>CatBoostRegressor</a></span></li><li><span><a href="#LightGBMRegressor" data-toc-modified-id="LightGBMRegressor-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>LightGBMRegressor</a></span></li></ul></li><li><span><a href="#Анализ-моделей" data-toc-modified-id="Анализ-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ моделей</a></span></li></ul></div>

# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# ## Постановка задачи

# %% [markdown]
# Разработать модель предсказания рычной стоимости автомобилей. Исходные данные содержат технические характеристики автомобилей, комплектации и цены.
#
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.
#
#
# **Примечание**
#
# Для оценки качества моделей ипользовать метрику RMSE.
#
#
# ### Описание данных
#
# Данные находятся в файле /datasets/autos.csv.
#
# **Признаки**
#
# - DateCrawled — дата скачивания анкеты из базы
# - VehicleType — тип автомобильного кузова
# - RegistrationYear — год регистрации автомобиля
# - Gearbox — тип коробки передач
# - Power — мощность (л. с.)
# - Model — модель автомобиля
# - Kilometer — пробег (км)
# - RegistrationMonth — месяц регистрации автомобиля
# - FuelType — тип топлива
# - Brand — марка автомобиля
# - NotRepaired — была машина в ремонте или нет
# - DateCreated — дата создания анкеты
# - NumberOfPictures — количество фотографий автомобиля
# - PostalCode — почтовый индекс владельца анкеты (пользователя)
# - LastSeen — дата последней активности пользователя
#
# **Целевой признак**
#
# - Price — цена (евро)

# %% [markdown]
# ## Подготовка данных

# %%
# !pip install hyperopt
# Out:
# ...
#      |████████████████████████████████| 1.6 MB 1.0 MB/s
# ...
#      |████████████████████████████████| 829 kB 47.4 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 2.0 MB 30.9 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=a1b6d9b3c5cdc23304b535dd0cf2032de238e61ff644056c2b3bcf1700bdc8ee
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2f/a0/d3/4030d9f80e6b3be787f19fc911b8e7aa462986a40ab1e4bb94
# Successfully built future
# ...

# %%
# !pip install category_encoders
# Out:
# ...
#      |████████████████████████████████| 80 kB 2.5 MB/s
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import category_encoders as ce
from scipy import stats
import lightgbm as lgb
import time

from hyperopt import hp, tpe, Trials, STATUS_OK
from hyperopt.fmin import fmin
from functools import partial

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
pd.options.mode.chained_assignment = None

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import GridSearchCV

from catboost import CatBoostRegressor

# %% [markdown]
# ### Первичный анализ данных

# %%
data = pd.read_csv('/datasets/autos.csv')

# %%
data.columns
# Out:
# Index(['DateCrawled', 'Price', 'VehicleType', 'RegistrationYear', 'Gearbox',
#        'Power', 'Model', 'Kilometer', 'RegistrationMonth', 'FuelType', 'Brand',
#        'NotRepaired', 'DateCreated', 'NumberOfPictures', 'PostalCode',
#        'LastSeen'],
#       dtype='object')

# %% [markdown]
# Приведем названия столбцов к удобному для работы виду

# %%
data.columns = ['date_crawled', 'price', 'vehicle_type', 'registration_year', 'gearbox',
       'power', 'model', 'kilometer', 'registration_month', 'fuel_type', 'brand',
       'not_repaired', 'date_created', 'number_of_pictures', 'postal_code',
       'last_seen']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        354369 non-null  object
#  1   price               354369 non-null  int64
#  2   vehicle_type        316879 non-null  object
#  3   registration_year   354369 non-null  int64
#  4   gearbox             334536 non-null  object
#  5   power               354369 non-null  int64
#  6   model               334664 non-null  object
#  7   kilometer           354369 non-null  int64
#  8   registration_month  354369 non-null  int64
#  9   fuel_type           321474 non-null  object
#  10  brand               354369 non-null  object
#  11  not_repaired        283215 non-null  object
#  12  date_created        354369 non-null  object
#  13  number_of_pictures  354369 non-null  int64
#  14  postal_code         354369 non-null  int64
# ...

# %%
data.head()
# Out:
#           date_crawled  price vehicle_type  registration_year gearbox  power  \
# 0  2016-03-24 11:52:17    480          NaN               1993  manual      0
# 1  2016-03-24 10:58:45  18300        coupe               2011  manual    190
# 2  2016-03-14 12:52:21   9800          suv               2004    auto    163
# 3  2016-03-17 16:54:04   1500        small               2001  manual     75
# 4  2016-03-31 17:25:20   3600        small               2008  manual     69
#
#    model  kilometer  registration_month fuel_type       brand not_repaired  \
# 0   golf     150000                   0    petrol  volkswagen          NaN
# 1    NaN     125000                   5  gasoline        audi          yes
# 2  grand     125000                   8  gasoline        jeep          NaN
# 3   golf     150000                   6    petrol  volkswagen           no
# 4  fabia      90000                   7  gasoline       skoda           no
#
# ...

# %% [markdown]
# ### Устранение дубликатов

# %% [markdown]
# Проверим таблицу на наличие явных дубликатов

# %%
data[data.duplicated()]
# Out:
#                date_crawled  price vehicle_type  registration_year gearbox  \
# 171088  2016-03-08 18:42:48   1799        coupe               1999    auto
# 231258  2016-03-28 00:56:10   1000        small               2002  manual
# 258109  2016-04-03 09:01:15   4699        coupe               2003    auto
# 325651  2016-03-18 18:46:15   1999        wagon               2001  manual
#
#         power   model  kilometer  registration_month fuel_type          brand  \
# 171088    193     clk      20000                   7    petrol  mercedes_benz
# 231258     83   other     150000                   1    petrol         suzuki
# 258109    218     clk     125000                   6    petrol  mercedes_benz
# 325651    131  passat     150000                   7  gasoline     volkswagen
#
#        not_repaired         date_created  number_of_pictures  postal_code  \
# 171088           no  2016-03-08 00:00:00                   0        89518
# ...

# %% [markdown]
# Удалим явные дубликаты и проверим результат операции

# %%
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Есть подозрение, что в таблицу могли быть повторно загружены строки без удаления их более ранних версий. Проверим, исключив столбец date_crawled, по которому они могут отличаться.

# %%
data.drop(['date_crawled'], axis=1).duplicated().sum()
# Out:
# 85

# %% [markdown]
# Таких строк в таблице оказалось 85, также их удалим.

# %%
data = data.drop(data[data.drop(['date_crawled'], axis=1).duplicated() == True].index, axis=0)

# %% [markdown]
# Учитывая особенности источника данных, можно предположить, что в таблице могут присутстовать дубликаты, появившися в следствие создания одним пользователем нескольких одинаковых объявлений. Найдем такие строки, исключив из таблицы столбцы  date_crawled, date_created, last_seen.

# %%
data.drop(['date_crawled', 'date_created', 'last_seen'], axis=1).duplicated().sum()
# Out:
# 21244

# %% [markdown]
# Предположение подтвердилось, таких строк оказалось больше 21 тыс. Удалим их из таблицы.

# %%
data = data.drop(data[data.drop(['date_crawled', 'date_created', 'last_seen'], 
                                axis=1).duplicated() == True].index, axis=0)

# %% [markdown]
# Пойдем еще дальше и предположим, что пользователи при повторном размещении объявлений о продаже могли не всегда точно указывать значение в атрибуте not_repaired. Это может быть связано как с умышленным сокрытием информации, так и с невнимательностью ввиду необязательности заполнения данного поля формы. Это потверждает и самое большое количество отсутствующих в данном столбце значений (больше 70 тыс.). Посмотрим сколько таких дубликатов в таблице

# %%
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated().sum()
# Out:
# 2919

# %% [markdown]
# а также распределение по значениям

# %%
data[data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated()]['not_repaired'].value_counts()
# Out:
# no     1330
# yes     306
# Name: not_repaired, dtype: int64

# %% [markdown]
# Из 2919 строк у 1276 в столбце not_repaired присутствует значение NaN. Удалим дубликаты из таблицы, но не все сразу, а последовательно, исходя из следующих соображений. Сначала удалим те дубликаты, у которых в столбце not_repaired установлено значение "yes" (т.е. без ремонта), т.к. в оставшейся строке в столбце not_repaired может присутствовать значение "no" (был ремонт) или NaN (неизвестно). Вполне логично, что последние два значения должны существенно влиять на цену автомобиля и давать определенный дисконт.

# %%
data = data[~((data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated()) & (data.not_repaired == "yes"))]

# %%
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated().sum()
# Out:
# 2613

# %% [markdown]
# Осталось 2613 строки дубликатов. Теперь удалим строки, у которых в столбце not_repaired присутствует значение NaN, а затем все остальные.

# %%
data = data[~((data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated()) & (data.not_repaired != "no"))]
data = data[~(data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated())]

# %%
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired'], 
               axis=1).duplicated().sum()
# Out:
# 0

# %% [markdown]
# Аналогичным образом рассуждая, предположим, что в таблице есть дубликаты, которые отличаются только значением в столбце vehicle_type. Эти строки вполне можно назвать дубликатами, т.к. при совпадении бренда и модели автомобиля, года регистрации, мощности, объема двигателя, цены и т.д., а также индекса, пользователя, разместившего объявления,  вероятность того, что эти объявления будут соответствовать разным автомобилям, очень мала. Разные значения в столбце vehicle_type этих строк объясняютя необязательностью заполнения соответствующего поля в форме сайта, т.к. в столбце отсутствуют больше 10% значений или невнимательностью пользователя, нелучшим юзабилити сайта. Проверим, сколько таких дубликатов может быть

# %%
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated().sum()
# Out:
# 1386

# %%
data['vehicle_type'].value_counts()
# Out:
# sedan          84765
# small          74137
# wagon          60236
# bus            26826
# convertible    18748
# coupe          15142
# suv            11019
# other           3179
# Name: vehicle_type, dtype: int64

# %% [markdown]
# Удалим прежде всего те строки, в столбце vehicle_type которых присутствует значение NaN

# %%
data = data[~((data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated()) & (data.vehicle_type != data.vehicle_type))]

# %%
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated().sum()
# Out:
# 1353

# %% [markdown]
# и значение other

# %%
data = data[~((data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated()) & (data.vehicle_type == 'other'))]
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated().sum()
# Out:
# 1296

# %% [markdown]
# а затем все остальные

# %%
data = data[~(data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated())]
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type'], 
               axis=1).duplicated().sum()
# Out:
# 0

# %% [markdown]
# Вышеперечисленные заключения применимы и для столбца fuel_type, соответствующего типу топлива. Проведем для него аналогичную процедуру.

# %%
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated().sum()
# Out:
# 1251

# %%
data['fuel_type'].value_counts()
# Out:
# petrol      200226
# gasoline     90744
# lpg           4884
# cng            524
# hybrid         225
# other          200
# electric        87
# Name: fuel_type, dtype: int64

# %%
data = data[~((data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated()) & (data.fuel_type != data.fuel_type))]
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated().sum()
# Out:
# 710

# %%
data = data[~((data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated()) & (data.fuel_type == 'other'))]
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated().sum()
# Out:
# 707

# %%
data = data[~(data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated())]
data.drop(['date_crawled', 'date_created', 'last_seen', 'not_repaired', 'vehicle_type', 'fuel_type'], 
               axis=1).duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дальнейший поиск дубликатов на основе наших предположений кажется сомнительным. Пока остановимся на этам этапе. И удалим сразу столбец number_of_pictures, который никак не влияет на оценку стоимости автомобиля.

# %%
data = data.drop(['number_of_pictures'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327480 entries, 0 to 354368
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        327480 non-null  object
#  1   price               327480 non-null  int64
#  2   vehicle_type        291627 non-null  object
#  3   registration_year   327480 non-null  int64
#  4   gearbox             308553 non-null  object
#  5   power               327480 non-null  int64
#  6   model               308586 non-null  object
#  7   kilometer           327480 non-null  int64
#  8   registration_month  327480 non-null  int64
#  9   fuel_type           296180 non-null  object
#  10  brand               327480 non-null  object
#  11  not_repaired        261178 non-null  object
#  12  date_created        327480 non-null  object
#  13  postal_code         327480 non-null  int64
#  14  last_seen           327480 non-null  object
# ...

# %% [markdown]
# ### Целевой признак price

# %%
data['price'].describe()
# Out:
# count    327480.000000
# mean       4376.643526
# std        4507.688764
# min           0.000000
# 25%        1000.000000
# 50%        2690.000000
# 75%        6299.000000
# max       20000.000000
# Name: price, dtype: float64

# %%
data.query('price < 150')['price'].count()
# Out:
# 13893

# %%
data.query('price < 150').tail()
# Out:
#                date_crawled  price vehicle_type  registration_year gearbox  \
# 354238  2016-03-20 14:55:07      0        small               2002  manual
# 354248  2016-03-24 13:48:05      0        small               1999  manual
# 354277  2016-03-10 22:55:50      0        small               1999  manual
# 354309  2016-03-09 22:37:41     99        small               1999  manual
# 354364  2016-03-21 09:50:58      0          NaN               2005  manual
#
#         power   model  kilometer  registration_month fuel_type       brand  \
# 354238     60  fiesta     150000                   3    petrol        ford
# 354248     53   swift     150000                   3    petrol      suzuki
# 354277     37   arosa     150000                   7    petrol        seat
# 354309     60   arosa     150000                   1    petrol        seat
# 354364      0    colt     150000                   7    petrol  mitsubishi
#
# ...

# %% [markdown]
# В столбце price присутствуют значения =0 и значения меньше 150 Евро. Вполне возможно, что некоторые автомобили отдаются бесплатно, но таких объявлений около 10000 и это не старые автомобили. Срок регистрации некоторых из них после 2010 года. Видимо, пользователем цена не была установлена в объявлении, либо произошел какой-то сбой при выгрузке объявлений и часть данных была потеряна. Стоимость автомобилей меньше 150 Евро также кажется несколько нереальной, также включим их в список на удаление. Всего таких строк около 4%, на результаты построения модели это не должно повлиять.

# %%
data = data.loc[data['price'] >= 150]

# %%
data['price'] = data['price'].astype('uint16')

# %%
data['price'].plot(kind='hist', bins=20, figsize=(10, 6))


plt.title("Распределение значений стоимости автомобиля")
plt.ylabel('Количество объявлений')
plt.xlabel("Стоимость автомобиля, евро")
plt.grid()
plt.show()

# %% [markdown]
# ### Категориальные признаки

# %% [markdown]
# Разобъем исходную выборку данных на тренировочную и тестовую выборки. Обработку будем проводить над таблицей data, предварительно по индексам очистив значения, принадлежащие test_features, чтобы не произошел эффект утечки данных.

# %%
train_features, test_features, train_target, test_target = train_test_split(data.drop(['price'], axis=1), data['price'], 
                                                                              test_size=0.25, random_state=12345)

# %%
train_features.shape
# Out:
# (235190, 14)

# %%
test_features.shape
# Out:
# (78397, 14)

# %% [markdown]
# Общий анализ будем проводить на исходном датафрейме data, а преобразования - уже на созданных выборках.

# %% [markdown]
# **brand**

# %%
data['brand'].unique()
# Out:
# array(['volkswagen', 'audi', 'jeep', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'opel', 'seat',
#        'citroen', 'honda', 'fiat', 'mini', 'smart', 'hyundai',
#        'alfa_romeo', 'subaru', 'volvo', 'mitsubishi', 'kia', 'suzuki',
#        'lancia', 'sonstige_autos', 'toyota', 'chevrolet', 'dacia',
#        'daihatsu', 'chrysler', 'jaguar', 'daewoo', 'rover', 'porsche',
#        'saab', 'trabant', 'land_rover', 'lada'], dtype=object)

# %% [markdown]
# Вопросов к данным в столбце brand нет.

# %% [markdown]
# **model**

# %%
data['model'].unique()
# Out:
# array(['golf', nan, 'grand', 'fabia', '3er', '2_reihe', 'c_max',
#        '3_reihe', 'passat', 'navara', 'ka', 'polo', 'twingo', 'a_klasse',
#        'scirocco', '5er', 'meriva', 'arosa', 'other', 'c4', 'civic',
#        'transporter', 'punto', 'e_klasse', 'clio', 'kadett', 'kangoo',
#        'one', 'fortwo', '1er', 'b_klasse', 'signum', 'astra', 'a8',
#        'jetta', 'fiesta', 'c_klasse', 'micra', 'vito', 'sprinter', '156',
#        'escort', 'forester', 'xc_reihe', 'scenic', 'a4', 'a1', 'insignia',
#        'combo', 'focus', 'tt', 'corsa', 'a6', 'jazz', 'omega', 'slk',
#        '7er', '80', '147', '100', 'z_reihe', 'sportage', 'sorento', 'v40',
#        'ibiza', 'mustang', 'eos', 'touran', 'getz', 'a3', 'almera',
#        'megane', 'lupo', 'r19', 'zafira', 'caddy', 'mondeo', 'cordoba',
#        'colt', 'impreza', 'vectra', 'berlingo', 'tiguan', 'i_reihe',
#        'espace', 'sharan', '6_reihe', 'panda', 'up', 'seicento', 'ceed',
# ...

# %%
data['model'].isna().sum()
# Out:
# 16163

# %% [markdown]
# Пропущено около 5% значений. Заполним отсутствующие значения значением 'unknown' и заменим значение other на unknown, т.к. other фактически означает, что модели нет в списке из известных нам.

# %%
data['model'] = data['model'].fillna('unknown')
data.loc[data['model'] == 'other', 'model'] = 'unknown'
test_features.loc[data['model'] == 'other', 'model'] = 'unknown'

# %% [markdown]
# **vehicle_type**

# %%
data['vehicle_type'].unique()
# Out:
# array([nan, 'coupe', 'suv', 'small', 'sedan', 'convertible', 'bus',
#        'wagon', 'other'], dtype=object)

# %%
data['vehicle_type'].isna().sum()
# Out:
# 30715

# %% [markdown]
# Около 10% значений в столбце vehicle_type не заполнены. Попробуем их каким-либо образом восстановить, к примеру, по бренду и модели из других строк, выбрав наиболее популярное значение. Предварительно очистим в столбце vehicle_type все значения по индексам test_features, чтобы данные тестовой выборки не влияли на результат, и не произошла утечка данных.

# %%
data.loc[test_features.index, 'vehicle_type'] = np.nan

# %%
data['vehicle_type']  = data['vehicle_type'].fillna(data.groupby(
    ['brand', 'model'])['vehicle_type'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %%
data.query('vehicle_type != vehicle_type')
# Out:
#               date_crawled  price vehicle_type  registration_year gearbox  \
# 31129  2016-03-20 19:27:12  12500          NaN               2005    auto
#
#        power               model  kilometer  registration_month fuel_type  \
# 31129    296  range_rover_evoque     150000                   8  gasoline
#
#             brand not_repaired         date_created  postal_code  \
# 31129  land_rover           no  2016-03-20 00:00:00        61462
#
#                  last_seen
# 31129  2016-03-20 20:38:44

# %%
31129 in test_features.index
# Out:
# True

# %% [markdown]
# Удалим строку с индексом 31139 из таблиц, чтобы не пришлось для нее каждый раз писать строку кода.

# %%
test_features.drop(labels=[31129], axis=0, inplace=True)
data.drop(labels=[31129], axis=0, inplace=True)
test_target.drop(labels=[31129], axis=0, inplace=True)

# %% [markdown]
# **gearbox**

# %%
data['gearbox'].unique()
# Out:
# array(['manual', 'auto', nan], dtype=object)

# %%
data['gearbox'].isna().sum()
# Out:
# 15236

# %% [markdown]
# Аналогичным образом попробуем восстановить отсутствующие значения, выбрав наиболее популярные из сгруппированных по бренду и модели автомобиля данным.

# %%
data.loc[test_features.index, 'gearbox'] = np.nan

# %%
data['gearbox'] = data['gearbox'].fillna(data.groupby(
    ['brand', 'model'])['gearbox'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %% [markdown]
# **fuel_type**

# %%
data['fuel_type'].unique()
# Out:
# array(['petrol', 'gasoline', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electric'], dtype=object)

# %% [markdown]
# Вызывают вопросы возможные значения в столбце fuel_type. В столбце присутствуют значения petrol и gasoline, означающие одно и тоже - бензин, но нет значения для дизельного топлива - diesel или fuel. Возможно, под одним из значений petrol, gasoline разработчиками сайта подразумевалось как раз дизельное топливо, но из-за неоднозначности их решения автомобили с бензиновым двигателем в столбце fuel_type могут иметь как значение petrol так и gasoline. Лучшим решением будет объединить эти значения в одно, к примеру - petrol.

# %%
data.loc[data['fuel_type'] == 'gasoline', 'fuel_type'] = 'petrol' 
test_features.loc[test_features['fuel_type'] == 'gasoline', 'fuel_type'] = 'petrol'

# %%
data['fuel_type'].isna().sum()
# Out:
# 26528

# %%
data.loc[test_features.index, 'fuel_type'] = np.nan

# %%
data['fuel_type'] = data['fuel_type'].fillna(data.groupby(
    ['brand', 'model'])['fuel_type'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %%
data['fuel_type'].unique()
# Out:
# array(['petrol', 'lpg', 'other', 'hybrid', 'cng', 'electric'],
#       dtype=object)

# %% [markdown]
# **not_repaired**

# %%
data['not_repaired'].unique()
# Out:
# array([nan, 'yes', 'no'], dtype=object)

# %% [markdown]
# Заменим значение NaN в столбце not_repaired в таблице на unknown

# %%
data['not_repaired'] = data['not_repaired'].fillna('unknown')

# %% [markdown]
# ### Модель на сырых данных

# %% [markdown]
# Для дальнейшей оценки качества построенной модели и в целом результатов исследования построим модель обучения на сырых данных, предварительно создав необходимые выборки и исключив лишние характеристики.

# %%
raw_data = data.drop(['last_seen', 'postal_code', 'date_crawled', 'date_created'], axis=1)

# %%
raw_data.describe()
# Out:
#                price  registration_year          power      kilometer  \
# count  313586.000000      313586.000000  313586.000000  313586.000000
# mean     4569.746915        2003.984980     111.310894  128610.604427
# std      4509.998384          71.781747     193.274591   37191.694826
# min       150.000000        1000.000000       0.000000    5000.000000
# 25%      1200.000000        1999.000000      69.000000  125000.000000
# 50%      2900.000000        2003.000000     105.000000  150000.000000
# 75%      6500.000000        2008.000000     143.000000  150000.000000
# max     20000.000000        9999.000000   20000.000000  150000.000000
#
#        registration_month
# count       313586.000000
# mean             5.780673
# std              3.689176
# min              0.000000
# 25%              3.000000
# 50%              6.000000
# 75%              9.000000
# max             12.000000

# %% [markdown]
# Проведем минимальную обработку данных, чтобы получить оценочную модель.

# %%
raw_data.query('price < 250')['price'].value_counts(ascending=False)
# Out:
# 200    1922
# 150    1563
# 199     268
# 180     242
# 220     154
# 190      97
# 230      90
# 170      80
# 249      73
# 160      65
# 175      57
# 222      52
# 240      40
# 225      35
# 210      16
# 235      14
# 195      12
# 185      10
# 229      10
# 215      10
# 155       9
# 245       8
# 189       8
# 179       7
# 219       5
# 169       5
# 159       4
# 165       4
# 156       3
# 198       3
# 209       2
# 205       2
# 211       2
# 188       2
# 238       1
# 202       1
# 233       1
# 166       1
# 162       1
# 158       1
# 217       1
# 193       1
# 181       1
# 177       1
# 173       1
# 157       1
# 248       1
# 236       1
# 224       1
# 196       1
# 192       1
# 243       1
# Name: price, dtype: int64

# %% [markdown]
# Избавимся от строк со значениями в столбце price <150

# %%
raw_data = raw_data.loc[raw_data['price'] >= 150]

# %%
raw_data.query('registration_year < 1886 | registration_year >2016')['registration_year'].count()
# Out:
# 13008

# %% [markdown]
# Удалим строки со значением даты регистрации в столбце registration_year вне диапазона 1886-2016 гг.

# %%
raw_data = raw_data.loc[(raw_data['registration_year'] > 1886) & (raw_data['registration_year'] <=2016)]

# %%
raw_data.query('power > 550').head()
# Out:
#       price vehicle_type  registration_year gearbox  power    model  \
# 1816   3200        small               2004  manual   1398  corolla
# 4060   3100        sedan               2005  manual    953     colt
# 5328    500        sedan               1999  manual   1001    astra
# 6296    599        small               2002  manual    603    matiz
# 6504   3000        small               2009  manual    771    punto
#
#       kilometer  registration_month fuel_type       brand not_repaired
# 1816       5000                   6    petrol      toyota           no
# 4060     150000                   4    petrol  mitsubishi           no
# 5328     150000                   7    petrol        opel      unknown
# 6296       5000                  11    petrol   chevrolet          yes
# 6504     125000                   0    petrol        fiat      unknown

# %% [markdown]
# Удалим строки со значением мощности автомобиля в столбце power >550.

# %%
raw_data = raw_data.loc[raw_data['power'] < 550]

# %%
raw_data.query('power < 40').head()
# Out:
#     price vehicle_type  registration_year gearbox  power   model  kilometer  \
# 0     480        sedan               1993  manual      0    golf     150000
# 15    450        small               1910  manual      0      ka       5000
# 32    245        sedan               1994  manual      0    golf     150000
# 37   1500          bus               2016  manual      0  kangoo     150000
# 54   4700        wagon               2005  manual      0  signum     150000
#
#     registration_month fuel_type       brand not_repaired
# 0                    0    petrol  volkswagen      unknown
# 15                   0    petrol        ford      unknown
# 32                   2    petrol  volkswagen           no
# 37                   1    petrol     renault           no
# 54                   0    petrol        opel           no

# %% [markdown]
# Для скорости построения первой модели пожертвуем также строками со значением мощности двигателя <40. Это около 10%.

# %%
raw_data = raw_data.loc[raw_data['power'] >= 40]

# %%
raw_data['registration_month'].unique()
# Out:
# array([ 5,  8,  6,  7, 10,  0, 12, 11,  2,  3,  1,  4,  9])

# %%
raw_data.query('registration_month == 0')['registration_month'].count()
# Out:
# 16493

# %% [markdown]
# Заменим значение =0 в столбце registration_month на ближайшее значение

# %%
raw_data.loc[raw_data['registration_month'] == 0, 'registration_month'] = np.nan
raw_data['registration_month'].bfill(inplace=True)

# %% [markdown]
# Сформируем выборки

# %%
raw_target = raw_data['price']
raw_features = raw_data.drop(['price'], axis=1)

# %%
train_features, test_features, train_target, test_target = train_test_split(raw_features, raw_target, 
                                            test_size=0.25, random_state=12345)

# %%
train_features.shape
# Out:
# (202068, 10)

# %%
test_features.shape
# Out:
# (67357, 10)

# %%
cat_features = ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']

# %%
train_features[cat_features] = train_features[cat_features].astype('category')

# %%
train_features['registration_month'] = train_features['registration_month'].astype('int')

# %%
model = CatBoostRegressor(iterations = 50, 
                          loss_function = "RMSE", l2_leaf_reg = 6,
                          nan_mode = None, cat_features=cat_features, verbose=10)

# %%
parameters = {'max_depth' : range(10, 13)}
grid = GridSearchCV(model, parameters, scoring='neg_root_mean_squared_error', cv=5)
grid.fit(train_features, train_target)
# Out:
# 0:	learn: 4520.4790877	total: 167ms	remaining: 8.18s
# 10:	learn: 3695.8187739	total: 1.17s	remaining: 4.15s
# 20:	learn: 3123.1455992	total: 2.31s	remaining: 3.2s
# 30:	learn: 2725.1899657	total: 3.34s	remaining: 2.05s
# 40:	learn: 2442.3913500	total: 4.43s	remaining: 973ms
# 49:	learn: 2258.8003998	total: 5.48s	remaining: 0us
# 0:	learn: 4516.5606734	total: 167ms	remaining: 8.18s
# 10:	learn: 3690.5570180	total: 1.15s	remaining: 4.09s
# 20:	learn: 3114.7781970	total: 2.25s	remaining: 3.11s
# 30:	learn: 2722.0021632	total: 3.17s	remaining: 1.94s
# 40:	learn: 2444.5697219	total: 4.17s	remaining: 916ms
# 49:	learn: 2258.9601335	total: 5.12s	remaining: 0us
# 0:	learn: 4507.9279117	total: 171ms	remaining: 8.37s
# 10:	learn: 3685.0207679	total: 1.25s	remaining: 4.42s
# 20:	learn: 3111.5993836	total: 2.36s	remaining: 3.25s
# 30:	learn: 2717.3029537	total: 3.75s	remaining: 2.3s
# 40:	learn: 2429.6580509	total: 4.81s	remaining: 1.06s
# 49:	learn: 2251.6642388	total: 5.75s	remaining: 0us
# ...

# %%
predicted_test = grid.predict(test_features)

# %%
mean_squared_error(test_target, predicted_test, squared=False)
# Out:
# 2226.2690107983312

# %% [markdown]
# На тестовых данных метрика rmse для модели CatBoost показала достаточно плохой результат. В среднем при предсказании стоимости автомобиля мы ошибаемся на 2226 Евро, что очень много. Попробуем поработать как с самими данными, так и с параметрами различных моделей, чтобы получить более адекватный результат. Теперь нам будет от чего отталкиваться при оценке результатов.

# %% [markdown]
# ### Предобработка числовых признаков

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 313586 entries, 0 to 354368
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        313586 non-null  object
#  1   price               313586 non-null  uint16
#  2   vehicle_type        313586 non-null  object
#  3   registration_year   313586 non-null  int64
#  4   gearbox             313586 non-null  object
#  5   power               313586 non-null  int64
#  6   model               313586 non-null  object
#  7   kilometer           313586 non-null  int64
#  8   registration_month  313586 non-null  int64
#  9   fuel_type           313586 non-null  object
#  10  brand               313586 non-null  object
#  11  not_repaired        313586 non-null  object
#  12  date_created        313586 non-null  object
#  13  postal_code         313586 non-null  int64
#  14  last_seen           313586 non-null  object
# ...

# %%
data.describe()
# Out:
#                price  registration_year          power      kilometer  \
# count  313586.000000      313586.000000  313586.000000  313586.000000
# mean     4569.746915        2003.984980     111.310894  128610.604427
# std      4509.998384          71.781747     193.274591   37191.694826
# min       150.000000        1000.000000       0.000000    5000.000000
# 25%      1200.000000        1999.000000      69.000000  125000.000000
# 50%      2900.000000        2003.000000     105.000000  150000.000000
# 75%      6500.000000        2008.000000     143.000000  150000.000000
# max     20000.000000        9999.000000   20000.000000  150000.000000
#
#        registration_month    postal_code
# count       313586.000000  313586.000000
# mean             5.780673   50877.500035
# std              3.689176   25742.923411
# min              0.000000    1067.000000
# 25%              3.000000   30539.000000
# 50%              6.000000   49624.000000
# 75%              9.000000   71554.000000
# ...

# %% [markdown]
# Вопросы вызывают максимальные значения в столбцах registration_year, power и минимальные значения в столбцах registration_year, price, power, registration_month, а также кванитили в распределении характеристики kilometer. Рассмотрим каждую из характеристик подробнее.

# %% [markdown]
# #### registration_year

# %%
data['registration_year'].unique()
# Out:
# array([1993, 2011, 2004, 2001, 2008, 1995, 2014, 1998, 2005, 1910, 2016,
#        2007, 2009, 2002, 2018, 1997, 1990, 2017, 1981, 2003, 1994, 1991,
#        1984, 2006, 1999, 2012, 2010, 2000, 1992, 2013, 1996, 1985, 1989,
#        2015, 1982, 1976, 1983, 1973, 1969, 1971, 1987, 1988, 1980, 1970,
#        1986, 1965, 1945, 1925, 1974, 1979, 1955, 1978, 1972, 1968, 1977,
#        1961, 1966, 1975, 1963, 1964, 1960, 1958, 1967, 1956, 3200, 1000,
#        1941, 9999, 8888, 1500, 2200, 4100, 1962, 1929, 1957, 1940, 3000,
#        2066, 1949, 2019, 1937, 1951, 1800, 1959, 1953, 1954, 1234, 5300,
#        9000, 2900, 6000, 5900, 5911, 1400, 5000, 1950, 4000, 1948, 1952,
#        8500, 1932, 3700, 3800, 4800, 1942, 7000, 1935, 1933, 1936, 1923,
#        2290, 1930, 1001, 9450, 1944, 2500, 1943, 1938, 1934, 1928, 5555,
#        5600, 1600, 1111, 1039, 2800, 1931, 4500, 1602, 7800, 1947, 1927,
#        7100, 1300, 8200, 1946])

# %%
data['registration_year'].min()
# Out:
# 1000

# %%
data['date_crawled'].max()
# Out:
# '2016-04-07 14:36:58'

# %% [markdown]
# В данных очень много аномалий: зачений, которые физически не могут присутствовать в таблице. Посмотрим, сколько таких строк в таблице, которые выходят за диапазон с 1886 по 2016 гг от года производства первого автомобиля до текущего года.

# %% [markdown]
# Сначала присвоим всем строкам в столбце registration_year, в которых текущее значение выходит за диапазон с 1886 по 2016 годы, значение NaN.

# %%
data.loc[test_features.index, 'registration_year'] = np.nan

test_features['registration_year'] = test_features['registration_year'].where(
    test_features['registration_year'].isin(range(1886, 2017)), np.nan)

data['registration_year'] = data['registration_year'].where(
    data['registration_year'].isin(range(1886, 2017)), np.nan)

# %% [markdown]
# Теперь сгруппируем данные по бренду и модели автомобиля, выделим столбец registration_year и заполним те ячейки, в которые мы  ранее внесли значение NaN, наиболее популярным значением года по выделенной группе.

# %%
data['registration_year'] = data['registration_year'].fillna(data.groupby(
    ['brand', 'model'])['registration_year'].transform(lambda x: x.mode()[0] if not x.mode().empty else np.nan))

# %% [markdown]
# Проверим результаты проведенных действий

# %%
data['registration_year'].unique()
# Out:
# array([1993., 2011., 2004., 2001., 2008., 1995., 2014., 1999., 2005.,
#        2006., 1910., 2016., 2000., 2009., 2002., 1997., 1990., 1981.,
#        1994., 2007., 1991., 1984., 2003., 2012., 1998., 2010., 1992.,
#        2013., 1996., 1985., 2015., 1982., 1976., 1983., 1973., 1969.,
#        1971., 1989., 1987., 1988., 1980., 1986., 1970., 1945., 1965.,
#        1925., 1974., 1979., 1955., 1978., 1972., 1968., 1961., 1977.,
#        1966., 1975., 1964., 1960., 1958., 1967., 1956., 1941., 1962.,
#        1929., 1957., 1963., 1940., 1949., 1937., 1951., 1959., 1953.,
#        1954., 1950., 1948., 1952., 1932., 1942., 1935., 1933., 1936.,
#        1923., 1930., 1944., 1938., 1934., 1943., 1928., 1931., 1947.,
#        1927., 1946.])

# %% [markdown]
# Значений года вне диапазана 1886-2016 в таблицах нет, отсутствующих значений тоже. Посмотрим на распределение данных по столбцу registration_year. Распределение будет оценочным, т.к. в таблице data перезаписаны данные из тестовой выборки. На последнемэ тапе мы их восстановим.

# %%
data['registration_year'] = data['registration_year'].astype('uint16')

# %%
data['registration_year'].plot(kind='hist', bins=20, figsize=(10, 6), alpha=0.8)

plt.title("Распределение количества объявлений (автомобилей) в зависимости от года регистрации")
plt.ylabel('Количество объявлений о продаже автомобилей')
plt.xlabel("Год регистрации автомобиля")
plt.grid()
plt.show()

# %% [markdown]
# От выбросов удалось избавиться, распределение данных близко к нормальному. Более подробно рассмотрим этот вопрос на следующем этапе.

# %% [markdown]
# #### kilometer

# %%
data['kilometer'].value_counts()
# Out:
# 150000    211070
# 125000     32670
# 100000     13122
# 90000      10342
# 80000       9002
# 70000       7864
# 60000       6632
# 50000       5604
# 5000        4485
# 40000       4380
# 30000       3885
# 20000       3502
# 10000       1028
# Name: kilometer, dtype: int64

# %% [markdown]
# Для удобства представления будем измерять пробег в тыс.км и приведем даные к соответствующему типу.

# %%
data['kilometer'] = (data['kilometer'] / 1000).astype('uint8')
test_features['kilometer'] = (test_features['kilometer'] / 1000).astype('uint8')

# %%
data['kilometer'].plot(kind='hist', bins=20, figsize=(10, 6), alpha=0.8)

plt.title("Распределение количества объявлений (автомобилей) в зависимости от пробега")
plt.ylabel('Количество объявлений о продаже автомобилей')
plt.xlabel("Пробег автомобиля, тыс. км")
plt.grid()
plt.show()

# %% [markdown]
# Видим, что значения в столбце kilometer дискретны, что, вероятно, обусловлено возможностью выбора на сайте при создании объявления строго определенных значений из списка, а не произвольным их заданием.

# %% [markdown]
# #### power

# %%
data['power'].unique()
# Out:
# array([    0,   190,   163,    75,    69,   102,   109,   125,   101,
#          105,   140,   115,   131,    60,   136,   160,   231,    90,
#           50,   118,   193,    99,   113,   218,   122,   129,    70,
#          306,    95,    61,   177,    80,   170,    55,   143,    64,
#          232,   150,   156,    82,   155,    54,   185,    87,   180,
#           86,    84,   224,   235,   200,   178,   265,    77,   110,
#          144,   120,   286,   116,   184,   126,   204,    88,   194,
#          305,   197,   179,   250,    45,   313,    41,   165,    98,
#          130,   114,   211,    56,   201,   213,    58,   107,    83,
#          174,   100,   220,    85,    73,   192,    68,    66,   299,
#           74,    52,   147,    65,   310,    71,    97,   239,   203,
#            5,   300,   103,   258,   320,    63,    81,   148,    44,
#          145,   280,   260,   104,   188,   333,   186,   117,   141,
# ...

# %%
data['power'].sort_values(ascending=False).head()
# Out:
# 219584    20000
# 299180    19312
# 114106    19211
# 132485    19208
# 63986     17932
# Name: power, dtype: int64

# %% [markdown]
# Больше 10% строк в данном в столбце имеют нулевые значения. Кроме того, в столбце присутствуют аномалии: подозрительно большие значения. Необходимо их каким-либо образом заполнить/преобразовать или исключить из таблицы. Рассмотрим сначала данные из столбца без учета выбросов в диапазоне от 40 до 550 лс.

# %%
data.query('power >= 40 & power <= 550')['power'].plot(kind='hist', bins=20, figsize=(10, 6))

plt.title("Распределение значений мощности двигателя в диапазоне от 40 до 550 лс")
plt.ylabel('Количество объявлений')
plt.xlabel("Мощность двигателя лс")
plt.grid()
plt.show()

# %% [markdown]
# **Мощность двигателя > 4000 лс**

# %% [markdown]
# Рассмотрим строки таблицы, где в столбце power присутствуют значения больше 4000 лс.

# %%
data[data['power'] > 4000].head()
# Out:
#               date_crawled  price vehicle_type  registration_year gearbox  \
# 7661   2016-04-02 19:25:25   1499        small               1999  manual
# 25232  2016-03-28 19:57:39  10900          bus               2009  manual
# 33952  2016-03-09 11:37:03   3740        small               2006  manual
# 44520  2016-03-10 22:37:21   2500        sedan               1998  manual
# 45053  2016-04-07 07:36:38  15800        small               2014    auto
#
#        power   model  kilometer  registration_month fuel_type       brand  \
# 7661    7515    lupo        150                   4    petrol  volkswagen
# 25232  10520   caddy        150                   6    petrol  volkswagen
# 33952   6920    aygo         90                  10    petrol      toyota
# 44520   7512    golf        150                   6    petrol  volkswagen
# 45053  10218  fortwo         30                   3    petrol       smart
#
#       not_repaired         date_created  postal_code            last_seen
# ...

# %% [markdown]
# Есть предположение, что по непонятным причинам к этим значениям было добалено еще 2 знака. Возможно, это связано с особенностями заполнения поля формы: к примеру, запрещено устанавливать точку/запятую, разделяющую разряды, поэтому при вводе пользователем дробного значения оно превращалась в целое с дополнительным знаком. Если разделить такие значения на 100, то они будут очень походить на реальные. К примеру, для автомобиля bmv 5er в столбце указано значение 17700 лс. Если посмотрим в один из справочников по автомобилям, то [увидим](https://auto.ru/catalog/cars/bmw/5er/specifications/harakteristiki-dvigatelya/), что с 2007 по 2010 годы выпускались автомобили этой серии в том числе с мощностью двигателя =177 лс. Проведем эту операцию с данными.

# %%
data.query('power >= 40 & power <= 70')['power'].count()
# Out:
# 45511

# %%
data.query('power >= 300 & power <= 550')['power'].count()
# Out:
# 2945

# %%
data.query('power >= 4000')['power'].count()
# Out:
# 79

# %% [markdown]
# Предел 4000 выбран, т.к. современные автомобили имеют мощность ориентировочно в диапазоне от 40 до 550 лс. Строк с минимальным значением мощности в диапазоне от 40 до 70 лс порядка 10%, а в диапазоне от 300 до 550 лс на порядок меньше, поэтому логично предположить, что, скорее всего, у выбросов со значением >4000 реальная мощность лежит в диапазоне от 40 лс, а не от 400 лс, если бы мы убирали в значениях не 2 знака, а 1 (см.следующий подпункт).

# %%
data.loc[data['power'] > 4000, 'power'] /= 100
test_features.loc[test_features['power'] > 4000, 'power'] /=  100

# %% [markdown]
# **Мощность двигателя от 550 до 4000 лс**

# %% [markdown]
# Аналогичным образом, как в предыдущем подпункте, если убрать один знак у значений в диапазоне от 550 до 4000, то полученная мощность автомобиля будет похожа на реальное значение мощности.

# %%
data.loc[(data['power'] <= 4000) & (data['power'] > 550), 'power'] /= 10
test_features.loc[(test_features['power'] <= 4000) & (test_features['power'] > 550), 'power'] /=  10

# %% [markdown]
# **Мощность двигателя < 40 лс**

# %% [markdown]
# Остальные аномальные значения, от 0 до 40 лс, заменим на медианные значения по группам. Кажется более логичным, что мощность двигателя в большей степени зависит от типа двигателя чем от бренда, поэтому сгруппируем данные по модели и типу двигателя.

# %%
test_features.loc[test_features['power'] < 40, 'power'] = np.nan
data.loc[data['power'] < 40, 'power'] = np.nan
data.loc[test_features.index, 'power'] = np.nan

# %%
data['power'].fillna(data.groupby(
    ['model', 'fuel_type'])['power'].transform(lambda x: x.median()), inplace=True)

# %% [markdown]
# Есть вероятность, что в некоторых группах при определеном совпадении типа двигателя и модели могли остаться значения NaN. Проверим.

# %%
data['power'].isna().sum()
# Out:
# 76

# %% [markdown]
# Так оно и есть. Оставшиеся значения получим на основе медианы в группах по бренду.

# %%
data['power'].fillna(data.groupby(
    ['brand'])['power'].transform(lambda x: x.median()), inplace=True)

# %%
data['power'].isna().sum()
# Out:
# 0

# %%
data['power'] = data['power'].astype('uint16')

# %%
data['power'].plot(kind='hist', bins=20, figsize=(10, 6))

plt.title("Распределение значений мощности двигателя")
plt.ylabel('Количество объявлений')
plt.xlabel("Мощность двигателя л.с")
plt.grid()
plt.show()

# %% [markdown]
# По оценочному графику распределения видим, что оно похоже на нормальное распределение. Аномальные значения удалось преобразовать в похожие на реальные значения.

# %% [markdown]
# #### registration_month

# %%
data['registration_month'].value_counts()
# Out:
# 3     30910
# 0     29532
# 6     28236
# 4     26461
# 5     26115
# 7     24535
# 10    23295
# 11    21666
# 12    21565
# 9     21275
# 1     20691
# 8     20266
# 2     19039
# Name: registration_month, dtype: int64

# %%
data[data['registration_month'] == 0].sample(5)
# Out:
#                date_crawled  price vehicle_type  registration_year gearbox  \
# 201487  2016-04-01 15:54:14   3200        wagon               2006  manual
# 249634  2016-04-01 16:52:22    299        wagon               2000  manual
# 108920  2016-03-20 12:53:46   3500        wagon               2002  manual
# 250344  2016-03-11 22:56:02    250        wagon               2005  manual
# 47792   2016-03-20 21:56:09   5000          suv               1964  manual
#
#         power    model  kilometer  registration_month fuel_type  \
# 201487    136   touran        150                   0    petrol
# 249634    115  unknown        150                   0    petrol
# 108920    102   passat        150                   0    petrol
# 250344    130   mondeo        150                   0    petrol
# 47792      80  unknown         20                   0    petrol
#
#                  brand not_repaired         date_created  postal_code  \
# ...

# %% [markdown]
# Каким либо образом установить связь между столбцом registration_month и остальными столбцами, чтобы восстановить данные в тех строках где значение =0, не представляеся возможным. Таких строк достаточно большое количество - около 10%, причем объявления размещались достаточно равномерно в течение всего года, нет какого-то однозначного лидера, поэтому отсутствующие значения просто заполним следующим элементом, чтобы не отдавать никому предпочтение.

# %%
data.loc[data['registration_month'] == 0, 'registration_month'] = np.nan
test_features.loc[test_features['registration_month'] == 0, 'registration_month'] = np.nan
data.loc[test_features.index, 'registration_month'] = np.nan

# %%
data['registration_month'].bfill(inplace=True)

# %% [markdown]
# Возможные оставшиеся незаполненные значения заполним наиболее популярным значением

# %%
data['registration_month'].fillna(data['registration_month'].mode()[0], inplace=True)

# %%
data['registration_month'] = data['registration_month'].astype('uint8')

# %%
data['registration_month'].plot(kind='hist', bins=20, figsize=(14, 6))

plt.title("Распределение объявлений по месяцам размещения")
plt.ylabel('Количество объявлений')
plt.xlabel("Месяцы размещения")
plt.grid()
plt.show()

# %% [markdown]
# ### Подготовка выборок

# %% [markdown]
# Перезапишем обработанные данные из таблицы data в таблицу с тенировочной выборкой train_features.

# %%
train_features = data.loc[train_features.index].drop('price', axis=1)

# %%
train_features.head()
# Out:
#                date_crawled vehicle_type  registration_year gearbox  power  \
# 192216  2016-03-09 23:56:32          bus               2002    auto    125
# 58174   2016-03-07 17:41:33        small               2010    auto     71
# 276337  2016-03-05 15:55:09  convertible               2005  manual    163
# 25941   2016-03-22 11:58:46  convertible               2005  manual    150
# 339382  2016-03-19 14:45:30        sedan               2004  manual    150
#
#          model  kilometer  registration_month fuel_type  brand not_repaired  \
# 192216  zafira        150                  12       lpg   opel           no
# 58174   fortwo         20                   8    petrol  smart           no
# 276337      a4        150                   3    petrol   audi           no
# 25941      3er        150                   5       lpg    bmw      unknown
# 339382     3er        150                   1    petrol    bmw          yes
#
# ...

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202068 entries, 192216 to 281771
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   date_crawled        202068 non-null  object
#  1   vehicle_type        202068 non-null  object
#  2   registration_year   202068 non-null  uint16
#  3   gearbox             202068 non-null  object
#  4   power               202068 non-null  uint16
#  5   model               202068 non-null  object
#  6   kilometer           202068 non-null  uint8
#  7   registration_month  202068 non-null  uint8
#  8   fuel_type           202068 non-null  object
#  9   brand               202068 non-null  object
#  10  not_repaired        202068 non-null  object
#  11  date_created        202068 non-null  object
#  12  postal_code         202068 non-null  int64
#  13  last_seen           202068 non-null  object
# dtypes: int64(1), object(9), uint16(2), uint8(2)
# ...

# %%
train_features.describe()
# Out:
#        registration_year          power      kilometer  registration_month  \
# count      202068.000000  202068.000000  202068.000000       202068.000000
# mean         2002.867579     121.144823     128.567413            6.373775
# std             6.421779      53.517449      36.537686            3.343986
# min          1910.000000      40.000000       5.000000            1.000000
# 25%          1999.000000      79.000000     125.000000            4.000000
# 50%          2003.000000     113.000000     150.000000            6.000000
# 75%          2007.000000     150.000000     150.000000            9.000000
# max          2016.000000     544.000000     150.000000           12.000000
#
#          postal_code
# count  202068.000000
# mean    51399.967625
# std     25772.628062
# min      1067.000000
# 25%     31020.000000
# 50%     50374.000000
# 75%     72250.000000
# max     99998.000000

# %% [markdown]
# А также заполним отсутствующие данные в таблице с тестовой выборкой test_features недостающими данными из таблицы data.

# %%
test_features.fillna(data.loc[test_features.index], inplace=True)

# %%
test_features.sample(5)
# Out:
#        vehicle_type  registration_year gearbox  power       model  kilometer  \
# 94007         sedan               1998    auto  125.0     carisma        150
# 157443          suv               2001  manual  177.0  freelander        125
# 239067        sedan               2005    auto  280.0          a8        150
# 26647         sedan               1994  manual   55.0        polo        125
# 186824  convertible               1999  manual  193.0         slk        150
#
#         registration_month fuel_type          brand not_repaired
# 94007                 11.0    petrol     mitsubishi           no
# 157443                 8.0    petrol     land_rover           no
# 239067                 1.0    petrol           audi           no
# 26647                  6.0    petrol     volkswagen           no
# 186824                 6.0    petrol  mercedes_benz      unknown

# %%
test_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67357 entries, 110832 to 101850
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vehicle_type        67357 non-null  object
#  1   registration_year   67357 non-null  int64
#  2   gearbox             67357 non-null  object
#  3   power               67357 non-null  float64
#  4   model               67357 non-null  object
#  5   kilometer           67357 non-null  uint8
#  6   registration_month  67357 non-null  float64
#  7   fuel_type           67357 non-null  object
#  8   brand               67357 non-null  object
#  9   not_repaired        67357 non-null  object
# dtypes: float64(2), int64(1), object(6), uint8(1)
# memory usage: 5.2+ MB

# %%
test_features.describe()
# Out:
#        registration_year         power     kilometer  registration_month
# count       67357.000000  67357.000000  67357.000000        67357.000000
# mean         2002.857892    120.686640    128.755660            6.377704
# std             6.428786     53.042163     36.313658            3.341683
# min          1910.000000     40.000000      5.000000            1.000000
# 25%          1999.000000     77.000000    125.000000            4.000000
# 50%          2003.000000    111.000000    150.000000            6.000000
# 75%          2007.000000    150.000000    150.000000            9.000000
# max          2016.000000    521.000000    150.000000           12.000000

# %% [markdown]
# Избавимся в тренировочной выборке от столбцов/характеристик, которые никак не могут влиять на стоимость автомобиля.

# %%
train_features.columns
# Out:
# Index(['date_crawled', 'vehicle_type', 'registration_year', 'gearbox', 'power',
#        'model', 'kilometer', 'registration_month', 'fuel_type', 'brand',
#        'not_repaired', 'date_created', 'postal_code', 'last_seen'],
#       dtype='object')

# %%
train_features = train_features.drop(['date_crawled', 'date_created', 'postal_code', 'last_seen'], axis=1)

# %%
test_features[['registration_year', 'power']] = test_features[['registration_year', 'power']].astype('uint16')
test_features['registration_month'] = test_features['registration_month'].astype('uint8')

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202068 entries, 192216 to 281771
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   vehicle_type        202068 non-null  object
#  1   registration_year   202068 non-null  uint16
#  2   gearbox             202068 non-null  object
#  3   power               202068 non-null  uint16
#  4   model               202068 non-null  object
#  5   kilometer           202068 non-null  uint8
#  6   registration_month  202068 non-null  uint8
#  7   fuel_type           202068 non-null  object
#  8   brand               202068 non-null  object
#  9   not_repaired        202068 non-null  object
# dtypes: object(6), uint16(2), uint8(2)
# memory usage: 11.9+ MB

# %%
test_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 67357 entries, 110832 to 101850
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   vehicle_type        67357 non-null  object
#  1   registration_year   67357 non-null  uint16
#  2   gearbox             67357 non-null  object
#  3   power               67357 non-null  uint16
#  4   model               67357 non-null  object
#  5   kilometer           67357 non-null  uint8
#  6   registration_month  67357 non-null  uint8
#  7   fuel_type           67357 non-null  object
#  8   brand               67357 non-null  object
#  9   not_repaired        67357 non-null  object
# dtypes: object(6), uint16(2), uint8(2)
# memory usage: 4.0+ MB

# %%
pd.plotting.scatter_matrix(train_features, figsize=(9, 9))
# Out:
# array([[<AxesSubplot:xlabel='registration_year', ylabel='registration_year'>,
#         <AxesSubplot:xlabel='power', ylabel='registration_year'>,
#         <AxesSubplot:xlabel='kilometer', ylabel='registration_year'>,
#         <AxesSubplot:xlabel='registration_month', ylabel='registration_year'>],
#        [<AxesSubplot:xlabel='registration_year', ylabel='power'>,
#         <AxesSubplot:xlabel='power', ylabel='power'>,
#         <AxesSubplot:xlabel='kilometer', ylabel='power'>,
#         <AxesSubplot:xlabel='registration_month', ylabel='power'>],
#        [<AxesSubplot:xlabel='registration_year', ylabel='kilometer'>,
#         <AxesSubplot:xlabel='power', ylabel='kilometer'>,
#         <AxesSubplot:xlabel='kilometer', ylabel='kilometer'>,
#         <AxesSubplot:xlabel='registration_month', ylabel='kilometer'>],
#        [<AxesSubplot:xlabel='registration_year', ylabel='registration_month'>,
#         <AxesSubplot:xlabel='power', ylabel='registration_month'>,
# ...

# %% [markdown]
# Какой-то явной корреляции между признаками не наблюдается, соответственно, эффекта мультиколлинеарности тоже.

# %% [markdown]
# #### Кодирование категориальных признаков

# %% [markdown]
# Для последующего построения моделей необходимо закодировать категориальные признаки.

# %% [markdown]
# **Признаки model и brand**

# %% [markdown]
# Категориальные признаки model и brand не являются независимыми, модели одного бренда не могут встретиться в моделях другого бренда. Кроме того, во многих брендах у нас содержится модель со значением unknown, которое имеет отношение толькок этой конкретной модели, а не ко вем моделям. Поэтому объединим эти два признака в один.

# %%
train_features['brand_model'] = train_features['brand'] + '_' + train_features['model']

# %%
train_features['brand_model'].head()
# Out:
# 192216     opel_zafira
# 58174     smart_fortwo
# 276337         audi_a4
# 25941          bmw_3er
# 339382         bmw_3er
# Name: brand_model, dtype: object

# %%
test_features['brand_model'] = test_features['brand'] + '_' + test_features['model']

# %% [markdown]
# Отдельно сохраним выборки для построения моделей градиентного спуска

# %%
test_features_gradient = test_features.drop(['model'], axis=1)
train_features_gradient = train_features.drop(['model'], axis=1)

# %% [markdown]
# В идеале значения в новом признаке brand_model желательно закодировать с помощью метода One-Hot Encoding, но в результате получится очень большое количество новых признаков/столбцов, равное количеству моделей во всех брендах. По условиям задачи у нас есть условие по скорости работы алгоритма, поэтому для признака brand_model вопользуемся методом OE.

# %%
all_brand_model = pd.DataFrame(pd.concat([train_features['brand_model'], test_features['brand_model']]).unique())

# %%
encoder = OrdinalEncoder()
encoder.fit(all_brand_model)
train_features['brand_model_trans'] = encoder.transform(train_features[['brand_model']])
test_features['brand_model_trans'] = encoder.transform(test_features[['brand_model']])

# %%
train_features = train_features.drop(['brand_model', 'model'], axis=1)
test_features = test_features.drop(['brand_model', 'model'], axis=1)

# %% [markdown]
# Признак model закодировали методом двоичного кодирования, а признак brand все таки закодируем методом OHE наряду с оставшимися категориальными признаками.

# %% [markdown]
# **Признаки vehicle_type, gearbox, fuel_type, not_repaired, brand**

# %% [markdown]
# Признаки vehicle_type, gearbox, fuel_type, not_repaired, brand закодируем с помощью OHE-метода.

# %%
all_data = pd.DataFrame(pd.concat([train_features, test_features]))
all_data = pd.get_dummies(all_data, drop_first = True)

# %%
all_data.head()
# Out:
#         registration_year  power  kilometer  registration_month  \
# 192216               2002    125        150                  12
# 58174                2010     71         20                   8
# 276337               2005    163        150                   3
# 25941                2005    150        150                   5
# 339382               2004    150        150                   1
#
#         brand_model_trans  vehicle_type_convertible  vehicle_type_coupe  \
# 192216              195.0                         0                   0
# 58174               242.0                         0                   0
# 276337               13.0                         1                   0
# 25941                23.0                         1                   0
# 339382               23.0                         0                   0
#
#         vehicle_type_other  vehicle_type_sedan  vehicle_type_small  ...  \
# ...

# %%
train_features = all_data.loc[train_features.index]
test_features = all_data.loc[test_features.index]

# %% [markdown]
# #### Масштабирование

# %% [markdown]
# Так как на данном этапе непонятно, на каком типе моделей мы остановимся, сразу проведем масштабирование признаков, хотя для некоторых моделей эта процедура может быть избыточной.

# %%
numeric = ['registration_year', 'power', 'kilometer', 'registration_month', 'brand_model_trans']

# %%
scaler = StandardScaler()
scaler.fit(train_features[numeric])
# Out:
# StandardScaler()

# %%
train_features[numeric] = scaler.transform(train_features[numeric])
test_features[numeric] = scaler.transform(test_features[numeric])

# %% [markdown]
# <a id='cat_feat'></a>Таким же бразом масштабируем числовые признаки в выборках для моделей градиентного спуска

# %%
numeric = ['registration_year', 'power', 'kilometer', 'registration_month']
scaler.fit(train_features_gradient[numeric])

train_features_gradient[numeric] = scaler.transform(train_features_gradient[numeric])
test_features_gradient[numeric] = scaler.transform(test_features_gradient[numeric])

# %%
cat = train_features_gradient.select_dtypes(include='object').columns

train_features_gradient[cat] = train_features_gradient[cat].astype('category')
test_features_gradient[cat] = test_features_gradient[cat].astype('category')

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Начнем разработку моделей с наиболее простых.

# %%
model_metric = pd.DataFrame(index=['rmse_train', 'rmse_test', 'time_stud', 'time_predict'], 
                            columns=['Tree', 'RF', 'LR', 'XGBR', 'Cat', 'LGBM'])

# %% [markdown]
# ### Дерево решений

# %% [markdown]
# Для подбора параметров модели воспользуемся бйесовской оптимизацией, реализованной в методе hyperopt

# %%
space = {'max_depth': hp.choice("max_depth", np.arange(1, 20, dtype = int))}

# %%
def hyperopt_score(params, x_train, y_train):
    model = DecisionTreeRegressor(**params, random_state = 12345)
    current_score = abs(cross_val_score(model, 
                                        x_train, 
                                        y_train, 
                                        scoring = 'neg_root_mean_squared_error', 
                                        cv = 5).mean())

    return {'loss': current_score, 'params': params, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(fn = partial(hyperopt_score, 
                         x_train=train_features, 
                         y_train=train_target),
            space=space, 
            algo=tpe.suggest, 
            max_evals = 20, 
            trials = trials)
# Out:
# 100%|██████████| 20/20 [01:27<00:00,  4.37s/trial, best loss: 1905.3835563036869]

# %%
model_metric.loc['rmse_train', 'Tree'] = round(trials.results[np.argmin([r['loss'] for r in trials.results])]['loss'])

# %%
t_start = time.process_time()

model = DecisionTreeRegressor(random_state = 12345, max_depth = best['max_depth'])
model.fit(train_features, train_target)

model_metric.loc['time_stud', 'Tree'] = round((time.process_time() - t_start), 2)

# %%
t_start = time.process_time()

predicted = model.predict(test_features)

model_metric.loc['rmse_test', 'Tree'] = round(mean_squared_error(test_target, predicted, squared = False))
model_metric.loc['time_predict', 'Tree'] = round((time.process_time() - t_start), 2)

# %%
model_metric
# Out:
#               Tree   RF   LR XGBR  Cat LGBM
# rmse_train    1905  NaN  NaN  NaN  NaN  NaN
# rmse_test     1874  NaN  NaN  NaN  NaN  NaN
# time_stud     1.19  NaN  NaN  NaN  NaN  NaN
# time_predict  0.03  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ### Случайный лес

# %%
space ={
    'max_depth': hp.choice("max_depth", np.arange(5, 16, dtype = int)),
    'n_estimators' : hp.choice("n_estimators", np.arange(5, 40, dtype = int)),
}

# %%
def hyperopt_score(params, x_train, y_train):
    model = RandomForestRegressor(**params, random_state=12345)
    current_score = abs(cross_val_score(model, 
                                        x_train, 
                                        y_train, 
                                        scoring = 'neg_root_mean_squared_error', 
                                        cv = 5).mean())

    return {'loss': current_score, 'params': params, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(fn=partial(hyperopt_score, 
                       x_train = train_features, 
                       y_train = train_target), 
            space = space, 
            algo = tpe.suggest, 
            max_evals = 20, 
            trials = trials)
# Out:
# 100%|██████████| 20/20 [18:39<00:00, 55.99s/trial, best loss: 1681.8733752441713]

# %%
model_metric.loc['rmse_train', 'RF'] = round(trials.results[np.argmin([r['loss'] for r in trials.results])]['loss'])

# %%
t_start = time.process_time()

model = RandomForestRegressor(
    random_state = 12345, 
    n_estimators = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['n_estimators'], 
    max_depth = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['max_depth'])

model.fit(train_features, train_target)
model_metric.loc['time_stud', 'RF'] = round((time.process_time() - t_start), 2)

# %%
t_start = time.process_time()

predicted = model.predict(test_features)

model_metric.loc['rmse_test', 'RF'] = round(mean_squared_error(test_target, predicted, squared=False))
model_metric.loc['time_predict', 'RF'] = round((time.process_time() - t_start), 2)

# %%
model_metric
# Out:
#               Tree     RF   LR XGBR  Cat LGBM
# rmse_train    1905   1682  NaN  NaN  NaN  NaN
# rmse_test     1874   1686  NaN  NaN  NaN  NaN
# time_stud     1.19  30.25  NaN  NaN  NaN  NaN
# time_predict  0.03   0.38  NaN  NaN  NaN  NaN

# %% [markdown]
# ### Линейная регрессия

# %%
model = LinearRegression()
model_metric.loc['rmse_train', 'LR'] = round(abs(cross_val_score(model, 
                                                                 train_features, 
                                                                 train_target, 
                                                                 scoring = 'neg_root_mean_squared_error', 
                                                                 cv = 5).mean()))

# %%
t_start = time.process_time()

model.fit(train_features, train_target)

model_metric.loc['time_stud', 'LR'] = round((time.process_time() - t_start), 2)

# %%
t_start = time.process_time()

predicted = model.predict(test_features)

model_metric.loc['rmse_test', 'LR'] = round(mean_squared_error(test_target, predicted, squared = False))
model_metric.loc['time_predict', 'LR'] = round((time.process_time() - t_start), 2)

# %%
model_metric
# Out:
#               Tree     RF    LR XGBR  Cat LGBM
# rmse_train    1905   1682  2834  NaN  NaN  NaN
# rmse_test     1874   1686  2834  NaN  NaN  NaN
# time_stud     1.19  30.25  2.05  NaN  NaN  NaN
# time_predict  0.03   0.38  0.03  NaN  NaN  NaN

# %% [markdown]
# ### XGBRegressor

# %%
space ={
    'max_depth': hp.choice("max_depth", np.arange(5, 16, dtype = int)),
    'n_estimators' : hp.choice("n_estimators", np.arange(5, 40, dtype = int)),
}

# %%
def hyperopt_score(params, x_train, y_train):
    model = XGBRegressor(**params, random_state = 12345)
    current_score = abs(cross_val_score(model, 
                                        x_train, 
                                        y_train, 
                                        scoring = 'neg_root_mean_squared_error', 
                                        cv = 5).mean())

    return {'loss': current_score, 'params': params, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(fn=partial(hyperopt_score, 
                       x_train = train_features, 
                       y_train = train_target), 
            space = space, 
            algo = tpe.suggest, 
            max_evals = 10, 
            trials = trials)
# Out:
# 100%|██████████| 10/10 [40:11<00:00, 241.14s/trial, best loss: 1617.2389892578126]

# %%
model_metric.loc['rmse_train', 'XGBR'] = round(trials.results[np.argmin([r['loss'] for r in trials.results])]['loss'])

# %%
t_start = time.process_time()
model = XGBRegressor(random_state = 12345, 
                n_estimators = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['n_estimators'], 
                max_depth = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['max_depth'])

model.fit(train_features, train_target)

model_metric.loc['time_stud', 'XGBR'] = round((time.process_time() - t_start), 2)

# %%
t_start = time.process_time()

predicted = model.predict(test_features)

model_metric.loc['rmse_test', 'XGBR'] = round(mean_squared_error(test_target, predicted, squared=False))
model_metric.loc['time_predict', 'XGBR'] = round((time.process_time() - t_start), 2)

# %%
model_metric
# Out:
#               Tree     RF    LR   XGBR  Cat LGBM
# rmse_train    1905   1682  2834   1617  NaN  NaN
# rmse_test     1874   1686  2834   1622  NaN  NaN
# time_stud     1.19  30.25  2.05  65.79  NaN  NaN
# time_predict  0.03   0.38  0.03   0.36  NaN  NaN

# %% [markdown]
# ### CatBoostRegressor

# %% [markdown]
# Так как CatBoostRegressor может работать с категориальными признаками без их предварительного кодирования, попробуем создать модель с заранее подготовленными выборками.

# %%
space ={'max_depth': hp.choice("max_depth", np.arange(10, 16, dtype=int))}

# %%
def hyperopt_score(params, x_train, y_train):
    model = CatBoostRegressor(**params, 
                              iterations = 100, 
                              loss_function = "RMSE", 
                              l2_leaf_reg = 6,
                              cat_features = list(cat),
                              verbose = 25)
    
    current_score = abs(cross_val_score(model, 
                                        x_train, 
                                        y_train, 
                                        scoring = 'neg_root_mean_squared_error', 
                                        cv = 5).mean())

    return {'loss': current_score, 'params': params, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(fn=partial(hyperopt_score, 
                       x_train = train_features_gradient, 
                       y_train = train_target), 
            space = space, 
            algo = tpe.suggest, 
            max_evals = 10, 
            trials = trials,
            verbose=True)
# Out:
#   0%|          | 0/10 [00:00<?, ?trial/s, best loss=?]0:	learn: 4518.1996885	total: 224ms	remaining: 22.2s
# 25:	learn: 2861.5070021	total: 5s	remaining: 14.2s
# 50:	learn: 2177.4900215	total: 9.94s	remaining: 9.55s
# 75:	learn: 1895.0218560	total: 15.3s	remaining: 4.83s
# 99:	learn: 1771.8359047	total: 20.1s	remaining: 0us
# 0:	learn: 4513.1021321	total: 335ms	remaining: 33.1s
# 25:	learn: 2859.8421603	total: 5.6s	remaining: 15.9s
# 50:	learn: 2172.4290387	total: 12.1s	remaining: 11.6s
# 75:	learn: 1891.5221757	total: 17.1s	remaining: 5.39s
# 99:	learn: 1768.3967907	total: 21.9s	remaining: 0us
# 0:	learn: 4504.5478634	total: 202ms	remaining: 20s
# 25:	learn: 2853.8348640	total: 4.97s	remaining: 14.2s
# 50:	learn: 2170.8623431	total: 9.88s	remaining: 9.49s
# 75:	learn: 1891.3574855	total: 14.7s	remaining: 4.64s
# 99:	learn: 1771.4284060	total: 19.4s	remaining: 0us
# 0:	learn: 4513.5927337	total: 197ms	remaining: 19.5s
# 25:	learn: 2857.8567550	total: 4.92s	remaining: 14s
# ...

# %%
model_metric.loc['rmse_train', 'Cat'] = round(trials.results[np.argmin([r['loss'] for r in trials.results])]['loss'])

# %%
t_start = time.process_time()
model = CatBoostRegressor(iterations = 100, 
                          loss_function = "RMSE", 
                          l2_leaf_reg = 6,
                          max_depth = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['max_depth'])

model.fit(train_features_gradient, train_target, cat_features = list(cat), verbose = 10)

model_metric.loc['time_stud', 'Cat'] = round((time.process_time() - t_start), 2)
# Out:
# 0:	learn: 4511.2177351	total: 645ms	remaining: 1m 3s
# 10:	learn: 3655.3210566	total: 6.49s	remaining: 52.5s
# 20:	learn: 3058.6849524	total: 12.2s	remaining: 45.7s
# 30:	learn: 2657.2094176	total: 18.1s	remaining: 40.3s
# 40:	learn: 2354.8018342	total: 24s	remaining: 34.5s
# 50:	learn: 2150.1206943	total: 29.8s	remaining: 28.7s
# 60:	learn: 1995.9033228	total: 35.8s	remaining: 22.9s
# 70:	learn: 1895.5602244	total: 41.8s	remaining: 17.1s
# 80:	learn: 1828.6555907	total: 47.6s	remaining: 11.2s
# 90:	learn: 1777.1351073	total: 53.5s	remaining: 5.29s
# 99:	learn: 1733.9618385	total: 58.8s	remaining: 0us

# %%
t_start = time.process_time()

predicted = model.predict(test_features_gradient)

model_metric.loc['rmse_test', 'Cat'] = round(mean_squared_error(test_target, predicted, squared=False))
model_metric.loc['time_predict', 'Cat'] = round((time.process_time() - t_start), 2)

# %%
model_metric
# Out:
#               Tree     RF    LR   XGBR    Cat LGBM
# rmse_train    1905   1682  2834   1617   1788  NaN
# rmse_test     1874   1686  2834   1622   1786  NaN
# time_stud     1.19  30.25  2.05  65.79  59.19  NaN
# time_predict  0.03   0.38  0.03   0.36   0.08  NaN

# %% [markdown]
# ### LightGBMRegressor

# %% [markdown]
# Модель LightGBMRegressor также попробуем построить на выборках без предварительного кодирования категориальных признаков.

# %%
space ={
    'max_depth': hp.choice("max_depth", np.arange(5, 16, dtype=int)),
    'n_estimators' : hp.choice("n_estimators", np.arange(5, 60, dtype=int)),
}

# %%
def hyperopt_score(params, x_train, y_train):
    model = lgb.LGBMRegressor(**params, random_state = 12345)
    current_score = abs(cross_val_score(model, 
                                        x_train, 
                                        y_train, 
                                        scoring = 'neg_root_mean_squared_error', 
                                        cv = 5).mean())

    return {'loss': current_score, 'params': params, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(fn=partial(hyperopt_score, 
                       x_train = train_features_gradient, 
                       y_train = train_target), 
            space = space, 
            algo = tpe.suggest, 
            max_evals = 10, 
            trials = trials)
# Out:
# 100%|██████████| 10/10 [02:26<00:00, 14.69s/trial, best loss: 1662.1647194502534]

# %%
model_metric.loc['rmse_train', 'LGBM'] = round(trials.results[np.argmin([r['loss'] for r in trials.results])]['loss'])

# %%
t_start = time.process_time()
model = lgb.LGBMRegressor(random_state = 12345, 
                n_estimators = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['n_estimators'], 
                max_depth = trials.results[np.argmin([r['loss'] for r in trials.results])]['params']['max_depth'])

model.fit(train_features_gradient, train_target)

model_metric.loc['time_stud', 'LGBM'] = round((time.process_time() - t_start), 2)

# %%
t_start = time.process_time()

predicted = model.predict(test_features_gradient)

model_metric.loc['rmse_test', 'LGBM'] = round(mean_squared_error(test_target, predicted, squared = False))
model_metric.loc['time_predict', 'LGBM'] = round((time.process_time() - t_start), 2)

# %% [markdown]
# При построении модели LGBMRegressor с закодированными категориальными признаками результаты оказались даже несколько хуже чем при незакодированных признаках.

# %% [markdown]
# ## Анализ моделей

# %% [markdown]
# Посмотрим на результаты экспериментов

# %%
model_metric
# Out:
#               Tree     RF    LR   XGBR    Cat  LGBM
# rmse_train    1905   1682  2834   1617   1788  1662
# rmse_test     1874   1686  2834   1622   1786  1674
# time_stud     1.19  30.25  2.05  65.79  59.19  3.53
# time_predict  0.03   0.38  0.03   0.36   0.08  0.37

# %% [markdown]
# Наилучший результат на тестовой выборке по метрике $RMSE$ показала модель XGBRegressor =1622 Евро. Для реального внедрения такой модели в жизнь она конечно не подойдет: средняя ошибка при оценке стоимости автомобиля в 1622 Евро - это очень плохо. Чуть хуже оказалась модель LightGBMRegressor со средней ошибкой =1674 Евро. На третьем месте модель RandomForest с результатом =1686 Евро.
#
# По скорости обучения модель XGBRegressor оказалась наихудшей, результат =65.79, чуть лучше результат у CatBoostRegressor =59.19. Наилучший результат среди сложных моделей, сравнимый с показателями простых моделей (DecisionTree и RandomForest), показала модель LightGBMRegressor =3.53. По скорости предсказания среди сложных моделей на первом месте - CatBoostRegressor с результатом =0.08. XGBRegressor и LightGBMRegressor по скорости предсказания практически идентичны с результатом =0.36, у RandomForest аналогичный результат.
#
# По большому счету, разница в скорости предсказания между худшей и лучшей моделями по этому показателю хотя и составляет один порядок, в абослютных единицах это доли секунд, поэтому пользователю разница будет не заметна. На этот показатель при выборе модели можно не ориентироваться. Наиболее оптимальным выглядит выбор модели LightGBMRegressor, которая показала и хорошую скорость обучения =3.53 и не сильно отличающееся от модели XGBRegressor значение метрики $RMSE$ =1674 Евро.
#
# Стоит отметить, что после предобработки числовых данных все модели показали лучший результат в сравнении с моделью CatBoostRegressor, построенной на сырых данных с $RMSE$ =2226 Евро (модель линейной регресии в расчет не берем).
